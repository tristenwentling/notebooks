# %% [markdown]
# #### Working example with Bokeh

# %%
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

arr1 = np.random.logistic(1, 0.1, 50)
arr2 = np.random.logistic(1, 0.1, 50)
cmap = sns.cubehelix_palette(n_colors=20, start=0, light=1, as_cmap=True)
sns.kdeplot(arr1, arr2, cmap=cmap, shade=True);
plt.figure(num=None, figsize=(15, 15), dpi=80, facecolor='w', edgecolor='k')
plt.show(10,10)
# Out:
# /work/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:1297: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
from bokeh.layouts import gridplot
from bokeh.plotting import figure, output_notebook, show

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1c2d97ce-4455-4905-ad65-5de3a2f7e414">Loading BokehJS ...</span>
#     </div>

# %%
arrA = np.random.logistic(1, 0.1, 5000)
arrB = np.random.logistic(1, 0.1, 5000)
x, y = arrA * 50, arrB * 50

radii = np.random.random(size=5000) * 1.5
colors = ["#%02x%02x%02x" % (int(r), int(g), 150) for r, g in zip(50+2*x, 30+2*y)]
TOOLS="resize,crosshair,pan,wheel_zoom,box_zoom,reset,box_select,lasso_select"


p = figure(tools=TOOLS, x_range=(0,100), y_range=(0,100))
p.circle(x, y, radius=radii, fill_color=colors, fill_alpha=0.6, line_color=None)
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8beba4cb-1759-43e6-8f0b-5b433b5c1d38"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8beba4cb-1759-43e6-8f0b-5b433b5c1d38");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8beba4cb-1759-43e6-8f0b-5b433b5c1d38");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8beba4cb-1759-43e6-8f0b-5b433b5c1d38' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cfdb9e24-c5d4-433b-b905-d96da60b5796":{"roots":{"references":[{"attributes":{"callback":null,"end":100},"id":"cc885b38-c559-42b0-b355-60c12a9c75e7","type":"Range1d"},{"attributes":{"plot":null,"text":""},"id":"1fee979e-0853-4b54-9eea-71b87f39c8b5","type":"Title"},{"attributes":{},"id":"10cddd48-c58a-4166-b946-284048f3b946","type":"ToolEvents"},{"attributes":{},"id":"5a8e4c84-5fbe-4f9e-8119-1786809e2c33","type":"BasicTicker"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"80029eda-97fd-4ab8-a4a7-8551acdbde6e","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"dbf95f8d-65b8-4507-b291-f457332d8519","type":"Circle"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"3ad4be30-41c7-4a42-bb29-490a6b315cad","type":"ResetTool"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"78850762-6be8-4d36-8dc1-d43addcbffa6","type":"PanTool"},{"attributes":{"fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"xs_units":"screen","ys_units":"screen"},"id":"14d8d0b1-784b-4228-9bbd-a4152b9070a6","type":"PolyAnnotation"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"9e9b94ef-afd0-46e7-b1b3-1be5017b68f2","type":"ResizeTool"},{"attributes":{"overlay":{"id":"0349465f-66ae-4169-8be0-769c3d269e62","type":"BoxAnnotation"},"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"442aa7c4-15cd-4c17-aff0-a9b88a19064d","type":"BoxZoomTool"},{"attributes":{"callback":null,"overlay":{"id":"7a79d089-f1df-4764-99ae-b00ddba6fede","type":"BoxAnnotation"},"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"},"renderers":[{"id":"78dd81d4-cae6-4271-87e0-5be251f6a964","type":"GlyphRenderer"}]},"id":"479c1a21-acc0-41e8-a2da-b1149a906110","type":"BoxSelectTool"},{"attributes":{"callback":null,"end":100},"id":"a1e58579-a92b-4d8c-b9f6-9bde805088b1","type":"Range1d"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"c412a940-c931-43f0-ac34-9850f00b61bd","type":"CrosshairTool"},{"attributes":{"fill_alpha":{"value":0.6},"fill_color":{"field":"fill_color"},"line_color":{"value":null},"radius":{"field":"radius","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"64f6d9b9-5dbc-4c8e-9710-ad9f7d5bcfd1","type":"Circle"},{"attributes":{"callback":null,"overlay":{"id":"14d8d0b1-784b-4228-9bbd-a4152b9070a6","type":"PolyAnnotation"},"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"}},"id":"e522f890-6c6f-42f3-9f31-8835d3e8b4e8","type":"LassoSelectTool"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"0349465f-66ae-4169-8be0-769c3d269e62","type":"BoxAnnotation"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"7a79d089-f1df-4764-99ae-b00ddba6fede","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"1e66dcf8-aac5-4bde-90f6-f745151a860e","subtype":"Figure","type":"Plot"},"ticker":{"id":"43e75 ...
